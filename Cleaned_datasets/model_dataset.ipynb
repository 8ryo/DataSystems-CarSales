# %%
import pandas as pd

# %%
CarDataset = pd.read_csv('Australian Vehicle Prices.csv')

# %%
CarDataset.head(5)
# Out:
#            Brand    Year   Model               Car/Suv  \
# 0      Ssangyong  2022.0  Rexton  Sutherland Isuzu Ute
# 1             MG  2022.0     MG3             Hatchback
# 2            BMW  2022.0    430I                 Coupe
# 3  Mercedes-Benz  2011.0    E500                 Coupe
# 4        Renault  2022.0  Arkana                   SUV
#
#                                        Title UsedOrNew Transmission  \
# 0       2022 Ssangyong Rexton Ultimate (awd)      DEMO    Automatic
# 1  2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                      2022 BMW 430I M Sport      USED    Automatic
# 3           2011 Mercedes-Benz E500 Elegance      USED    Automatic
# 4                 2022 Renault Arkana Intens      USED    Automatic
#
#          Engine DriveType  FuelType FuelConsumption Kilometres   ColourExtInt  \
# 0  4 cyl, 2.2 L       AWD    Diesel  8.7 L / 100 km       5595  White / Black
# ...

# %%
model_table =  CarDataset[['Brand','Year', 'Model', "Title", 'Transmission']]

# %%
model_table.head()
# Out:
#            Brand    Year   Model                                      Title  \
# 0      Ssangyong  2022.0  Rexton       2022 Ssangyong Rexton Ultimate (awd)
# 1             MG  2022.0     MG3  2022 MG MG3 Auto Excite (with Navigation)
# 2            BMW  2022.0    430I                      2022 BMW 430I M Sport
# 3  Mercedes-Benz  2011.0    E500           2011 Mercedes-Benz E500 Elegance
# 4        Renault  2022.0  Arkana                 2022 Renault Arkana Intens
#
#   Transmission
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic

# %%
model_table['Year'] = model_table['Year'].astype('Int32')
# Out:
# /var/folders/qm/lc6r1s752bb1ls34svwcl3240000gn/T/ipykernel_91585/2703634576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_table['Year'] = model_table['Year'].astype('Int32')

# %%
model_table.head()
# Out:
#            Brand  Year   Model                                      Title  \
# 0      Ssangyong  2022  Rexton       2022 Ssangyong Rexton Ultimate (awd)
# 1             MG  2022     MG3  2022 MG MG3 Auto Excite (with Navigation)
# 2            BMW  2022    430I                      2022 BMW 430I M Sport
# 3  Mercedes-Benz  2011    E500           2011 Mercedes-Benz E500 Elegance
# 4        Renault  2022  Arkana                 2022 Renault Arkana Intens
#
#   Transmission
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic

# %%
model_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16734 entries, 0 to 16733
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         16733 non-null  object
#  1   Year          16733 non-null  Int32
#  2   Model         16733 non-null  object
#  3   Title         16733 non-null  object
#  4   Transmission  16733 non-null  object
# dtypes: Int32(1), object(4)
# memory usage: 604.8+ KB

# %%
model_table = model_table.drop_duplicates(subset="Title")

# %%
model_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8805 entries, 0 to 16733
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         8804 non-null   object
#  1   Year          8804 non-null   Int32
#  2   Model         8804 non-null   object
#  3   Title         8804 non-null   object
#  4   Transmission  8804 non-null   object
# dtypes: Int32(1), object(4)
# memory usage: 386.9+ KB

# %%
#model_table.to_csv('Model_dimension_table.csv')

# %%
Specific_car_dimensionTable = CarDataset[['Brand','Model','Year','UsedOrNew']]

# %%
Specific_car_dimensionTable["Year"] = model_table['Year'].astype('Int32')
# Out:
# /var/folders/qm/lc6r1s752bb1ls34svwcl3240000gn/T/ipykernel_91585/1316977522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Specific_car_dimensionTable["Year"] = model_table['Year'].astype('Int32')

# %%
Specific_car_dimensionTable.head()
# Out:
#            Brand   Model  Year UsedOrNew
# 0      Ssangyong  Rexton  2022      DEMO
# 1             MG     MG3  2022      USED
# 2            BMW    430I  2022      USED
# 3  Mercedes-Benz    E500  2011      USED
# 4        Renault  Arkana  2022      USED

# %%
#Specific_car_dimensionTable.to_csv("Specfic_Car_dimensionTable.csv")

# %%
CarDataset['Year'] = CarDataset['Year'].astype('Int32')

# %%
CarDataset.head()
# Out:
#            Brand  Year   Model               Car/Suv  \
# 0      Ssangyong  2022  Rexton  Sutherland Isuzu Ute
# 1             MG  2022     MG3             Hatchback
# 2            BMW  2022    430I                 Coupe
# 3  Mercedes-Benz  2011    E500                 Coupe
# 4        Renault  2022  Arkana                   SUV
#
#                                        Title UsedOrNew Transmission  \
# 0       2022 Ssangyong Rexton Ultimate (awd)      DEMO    Automatic
# 1  2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                      2022 BMW 430I M Sport      USED    Automatic
# 3           2011 Mercedes-Benz E500 Elegance      USED    Automatic
# 4                 2022 Renault Arkana Intens      USED    Automatic
#
#          Engine DriveType  FuelType FuelConsumption Kilometres   ColourExtInt  \
# 0  4 cyl, 2.2 L       AWD    Diesel  8.7 L / 100 km       5595  White / Black
# ...

# %%
CarDataset = CarDataset.drop(columns = ['Car/Suv'])

# %%
CarDataset.head()
# Out:
#            Brand  Year   Model                                      Title  \
# 0      Ssangyong  2022  Rexton       2022 Ssangyong Rexton Ultimate (awd)
# 1             MG  2022     MG3  2022 MG MG3 Auto Excite (with Navigation)
# 2            BMW  2022    430I                      2022 BMW 430I M Sport
# 3  Mercedes-Benz  2011    E500           2011 Mercedes-Benz E500 Elegance
# 4        Renault  2022  Arkana                 2022 Renault Arkana Intens
#
#   UsedOrNew Transmission        Engine DriveType  FuelType FuelConsumption  \
# 0      DEMO    Automatic  4 cyl, 2.2 L       AWD    Diesel  8.7 L / 100 km
# 1      USED    Automatic  4 cyl, 1.5 L     Front   Premium  6.7 L / 100 km
# 2      USED    Automatic    4 cyl, 2 L      Rear   Premium  6.6 L / 100 km
# 3      USED    Automatic  8 cyl, 5.5 L      Rear   Premium   11 L / 100 km
# 4      USED    Automatic  4 cyl, 1.3 L     Front  Unleaded    6 L / 100 km
#
# ...

# %%
CarDatasetNew = CarDataset.sort_values('Brand')

# %%
CarDatasetNew = CarDatasetNew.reset_index()

# %%
CarDatasetNew.head()
# Out:
#    index   Brand  Year  Model                                         Title  \
# 0     51  Abarth  2021    595                  2021 Abarth 595 Competizione
# 1   8479  Abarth  2021    595                  2021 Abarth 595 Competizione
# 2   6949  Abarth  2022    695                  2022 Abarth 695 Competizione
# 3   1046    Alfa  2014  Romeo         2014 Alfa Romeo Giulietta Distinctive
# 4   1717    Alfa  2015  Romeo  2015 Alfa Romeo Giulietta Quadrifoglio Verde
#
#   UsedOrNew Transmission        Engine DriveType FuelType FuelConsumption  \
# 0      USED       Manual  4 cyl, 1.4 L     Front  Premium    6 L / 100 km
# 1      USED    Automatic  4 cyl, 1.4 L     Front  Premium  5.8 L / 100 km
# 2      DEMO            -             -     Other        -               -
# 3      USED       Manual  4 cyl, 1.4 L     Front  Premium  5.8 L / 100 km
# 4      USED    Automatic  4 cyl, 1.7 L     Front  Premium    7 L / 100 km
#
# ...

# %%
CarDatasetNew = CarDatasetNew.drop(columns=["index"])

# %%
CarDatasetNew.head()
# Out:
#     Brand  Year  Model                                         Title  \
# 0  Abarth  2021    595                  2021 Abarth 595 Competizione
# 1  Abarth  2021    595                  2021 Abarth 595 Competizione
# 2  Abarth  2022    695                  2022 Abarth 695 Competizione
# 3    Alfa  2014  Romeo         2014 Alfa Romeo Giulietta Distinctive
# 4    Alfa  2015  Romeo  2015 Alfa Romeo Giulietta Quadrifoglio Verde
#
#   UsedOrNew Transmission        Engine DriveType FuelType FuelConsumption  \
# 0      USED       Manual  4 cyl, 1.4 L     Front  Premium    6 L / 100 km
# 1      USED    Automatic  4 cyl, 1.4 L     Front  Premium  5.8 L / 100 km
# 2      DEMO            -             -     Other        -               -
# 3      USED       Manual  4 cyl, 1.4 L     Front  Premium  5.8 L / 100 km
# 4      USED    Automatic  4 cyl, 1.7 L     Front  Premium    7 L / 100 km
#
#   Kilometres             ColourExtInt          Location CylindersinEngine  \
# ...

# %%
#CarDatasetNew.to_csv("Updated Car Dataset 1.csv")

# %% [markdown]
# ## Model Line Dimension Table

# %%
UpdatedCarDataset = pd.read_csv('Updated Car Dataset 1.csv')

# %%
UpdatedCarDataset.head()
# Out:
#    Unnamed: 0   Brand    Year  Model  \
# 0           0  Abarth  2021.0    595
# 1           1  Abarth  2021.0    595
# 2           2  Abarth  2022.0    695
# 3           3    Alfa  2014.0  Romeo
# 4           4    Alfa  2015.0  Romeo
#
#                                           Title UsedOrNew Transmission  \
# 0                  2021 Abarth 595 Competizione      USED       Manual
# 1                  2021 Abarth 595 Competizione      USED    Automatic
# 2                  2022 Abarth 695 Competizione      DEMO            -
# 3         2014 Alfa Romeo Giulietta Distinctive      USED       Manual
# 4  2015 Alfa Romeo Giulietta Quadrifoglio Verde      USED    Automatic
#
#          Engine DriveType FuelType FuelConsumption Kilometres  \
# 0  4 cyl, 1.4 L     Front  Premium    6 L / 100 km      13200
# 1  4 cyl, 1.4 L     Front  Premium  5.8 L / 100 km      14901
# 2             -     Other        -               -         17
# ...

# %%
model_line_dimension_table =  UpdatedCarDataset[["Model", 'Brand',  'DriveType', 'BodyType']]

# %%
model_line_dimension_table.head()
# Out:
#    Model   Brand DriveType   BodyType
# 0    595  Abarth     Front  Hatchback
# 1    595  Abarth     Front  Hatchback
# 2    695  Abarth     Other  Hatchback
# 3  Romeo    Alfa     Front  Hatchback
# 4  Romeo    Alfa     Front  Hatchback

# %%
model_line_dimension_table.to_csv("Model Line Dimension Tabele.csv")

# %% [markdown]
# ## Car Sales Fact Table

# %%
CarSalesFactTable = UpdatedCarDataset[["Price", 'Kilometres', "Year"]]

# %%
CarSalesFactTable.head()
# Out:
#    Price Kilometres    Year
# 0  36990      13200  2021.0
# 1  37990      14901  2021.0
# 2  44824         17  2022.0
# 3  12995     136311  2014.0
# 4  24995      98446  2015.0

# %%
CarSalesFactTable['Age of Car'] = 2024 - CarSalesFactTable['Year']
# Out:
# /var/folders/qm/lc6r1s752bb1ls34svwcl3240000gn/T/ipykernel_91585/4181711199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CarSalesFactTable['Age of Car'] = 2024 - CarSalesFactTable['Year']

# %%
CarSalesFactTable
# Out:
#        Price Kilometres    Year  Age of Car
# 0      36990      13200  2021.0         3.0
# 1      37990      14901  2021.0         3.0
# 2      44824         17  2022.0         2.0
# 3      12995     136311  2014.0        10.0
# 4      24995      98446  2015.0         9.0
# ...      ...        ...     ...         ...
# 16729  14999     141000  2013.0        11.0
# 16730  51888      80770  2017.0         7.0
# 16731  79990      34767  2022.0         2.0
# 16732  41990      54734  2019.0         5.0
# 16733    NaN        NaN     NaN         NaN
#
# [16734 rows x 4 columns]

# %%
#CarSalesFactTable.to_csv("Car Sales Fact Table.csv")
